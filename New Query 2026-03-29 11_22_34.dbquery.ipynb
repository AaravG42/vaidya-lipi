-- %%
-- Run in SQL editor or notebook
GRANT USE CATALOG ON CATALOG workspace TO `23bcce37-d94e-48b5-986c-545c7f91b320`;
GRANT USE SCHEMA ON SCHEMA workspace.vaidya TO `23bcce37-d94e-48b5-986c-545c7f91b320`;
GRANT SELECT ON TABLE workspace.vaidya.patient_records TO `23bcce37-d94e-48b5-986c-545c7f91b320`;
-- GRANT INSERT ON TABLE workspace.vaidya.patient_records TO `23bcce37-d94e-48b5-986c-545c7f91b320`;
GRANT MODIFY ON TABLE workspace.vaidya.patient_records TO `23bcce37-d94e-48b5-986c-545c7f91b320`;
GRANT SELECT ON TABLE workspace.vaidya.health_alerts TO `23bcce37-d94e-48b5-986c-545c7f91b320`;
GRANT READ VOLUME ON VOLUME workspace.vaidya.models_and_indexes TO `23bcce37-d94e-48b5-986c-545c7f91b320`;

-- SHOW GRANTS ON TABLE workspace.vaidya.patient_records;
